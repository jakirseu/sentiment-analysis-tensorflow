# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.preprocessing.text import Tokenizer

# %% [markdown]
# **Load data**
#
# ---
#
#
# You can download the data as[ CSV format from Kaggle](https://www.kaggle.com/datasets/columbine/imdb-dataset-sentiment-analysis-in-csv-format).  So that you don't need to think about data compilation much. Just download the data and then upload the Train.csv in file area. If you want to use data from text file and learn more, try this [official tutorial](https://www.tensorflow.org/tutorials/keras/text_classification).

# %%
df = pd.read_csv('Train.csv')
df.head()
# Out:
#                                                 text  label
# 0  I grew up (b. 1965) watching and loving the Th...      0
# 1  When I put this movie in my DVD player, and sa...      0
# 2  Why do people who do not know what a particula...      0
# 3  Even though I have great interest in Biblical ...      0
# 4  Im a die hard Dads Army fan and nothing will e...      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    40000 non-null  object
#  1   label   40000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 625.1+ KB

# %%
x=df['text']
y=df['label']

# %% [markdown]
# **Split the data into training and testing set**
#
# ---

# %%
X_train, X_test , Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=50)

# %%
tokenizer = Tokenizer(num_words = 100, oov_token="<OOV>")
tokenizer.fit_on_texts(X_train)
word_index = tokenizer.word_index
# print word index aka dictionary
print(word_index)
# Out:
# {'<OOV>': 1, 'the': 2, 'and': 3, 'a': 4, 'of': 5, 'to': 6, 'is': 7, 'br': 8, 'in': 9, 'it': 10, 'i': 11, 'this': 12, 'that': 13, 'was': 14, 'as': 15, 'for': 16, 'with': 17, 'movie': 18, 'but': 19, 'film': 20, 'on': 21, 'you': 22, 'not': 23, 'are': 24, 'his': 25, 'have': 26, 'be': 27, 'one': 28, 'he': 29, 'all': 30, 'at': 31, 'by': 32, 'an': 33, 'they': 34, 'so': 35, 'who': 36, 'from': 37, 'like': 38, 'or': 39, 'just': 40, 'her': 41, 'about': 42, 'out': 43, 'if': 44, "it's": 45, 'has': 46, 'some': 47, 'there': 48, 'what': 49, 'good': 50, 'more': 51, 'when': 52, 'very': 53, 'up': 54, 'no': 55, 'time': 56, 'even': 57, 'my': 58, 'would': 59, 'she': 60, 'which': 61, 'really': 62, 'only': 63, 'see': 64, 'story': 65, 'their': 66, 'had': 67, 'can': 68, 'me': 69, 'were': 70, 'well': 71, 'than': 72, 'much': 73, 'we': 74, 'get': 75, 'been': 76, 'also': 77, 'bad': 78, 'will': 79, 'other': 80, 'do': 81, 'into': 82, 'great': 83, 'people': 84, 'him': 85, 'most': 86, 'because': 87, 'how': 88, 'first': 89, "don't": 90, 'them': 91, 'then': 92, 'make': 93, 'made': 94, 'its': 95, 'too': 96, 'way': 97, 'movies': 98, 'could': 99, 'any': 100, 'after': 101, 'characters': 102, 'think': 103, 'films': 104, 'watch': 105, 'two': 106, 'character': 107, 'many': 108, 'seen': 109, 'being': 110, 'love': 111, 'never': 112, 'acting': 113, 'plot': 114, 'life': 115, 'did': 116, 'where': 117, 'show': 118, 'best': 119, 'know': 120, 'little': 121, 'over': 122, 'ever': 123, 'off': 124, 'does': 125, 'better': 126, 'your': 127, 'end': 128, 'man': 129, 'still': 130, 'scene': 131, 'say': 132, 'these': 133, 'here': 134, 'why': 135, 'while': 136, 'scenes': 137, 'something': 138, 'such': 139, 'go': 140, 'through': 141, 'back': 142, 'those': 143, 'should': 144, 'real': 145, "i'm": 146, 'watching': 147, 'now': 148, 'thing': 149, "doesn't": 150, 'though': 151, "didn't": 152, 'years': 153, 'funny': 154, 'actors': 155, '10': 156, 'work': 157, 'old': 158, 'another': 159, 'before': 160, 'actually': 161, 'makes': 162, 'look': 163, 'nothing': 164, 'director': 165, 'going': 166, 'find': 167, 'same': 168, 'every': 169, 'new': 170, 'lot': 171, 'few': 172, 'part': 173, 'again': 174, 'down': 175, 'us': 176, 'cast': 177, 'things': 178, 'quite': 179, 'horror': 180, 'pretty': 181, 'want': 182, 'seems': 183, 'around': 184, 'world': 185, 'young': 186, 'however': 187, "can't": 188, 'enough': 189, 'got': 190, 'take': 191, 'fact': 192, 'thought': 193, 'big': 194, 'long': 195, 'give': 196, 'both': 197, "that's": 198, 'may': 199, "i've": 200, 'music': 201, 'between': 202, 'series': 203, 'right': 204, 'own': 205, 'action': 206, "isn't": 207, 'times': 208, 'comedy': 209, 'without': 210, 'must': 211, 'saw': 212, 'come': 213, 'always': 214, 'original': 215, 'guy': 216, 'interesting': 217, 'almost': 218, 'gets': 219, 'done': 220, 'role': 221, "there's": 222, 'least': 223, 'point': 224, 'whole': 225, 'far': 226, 'bit': 227, 'script': 228, "he's": 229, 'feel': 230, 'minutes': 231, 'last': 232, 'making': 233, 'anything': 234, 'family': 235, '2': 236, 'might': 237, 'probably': 238, 'since': 239, 'am': 240, 'kind': 241, 'tv': 242, 'performance': 243, 'yet': 244, 'away': 245, 'worst': 246, 'fun': 247, 'rather': 248, 'hard': 249, 'anyone': 250, 'sure': 251, 'girl': 252, 'played': 253, 'each': 254, 'woman': 255, 'day': 256, 'found': 257, 'especially': 258, 'looking': 259, 'our': 260, 'screen': 261, 'although': 262, 'trying': 263, 'believe': 264, 'everything': 265, 'having': 266, 'course': 267, 'set': 268, 'dvd': 269, 'goes': 270, 'three': 271, 'comes': 272, 'shows': 273, 'put': 274, 'ending': 275, 'maybe': 276, 'place': 277, 'main': 278, 'worth': 279, 'sense': 280, 'different': 281, 'book': 282, 'reason': 283, 'true': 284, 'once': 285, 'actor': 286, 'looks': 287, 'american': 288, 'play': 289, "wasn't": 290, 'job': 291, 'money': 292, 'effects': 293, 'together': 294, 'someone': 295, 'during': 296, 'watched': 297, 'seem': 298, 'high': 299, 'war': 300, 'instead': 301, 'half': 302, '1': 303, 'plays': 304, 'year': 30 ...

# %%
vocab_size = 5000
embedding_dim = 32
max_length = 75
trunc_type='post'
pad_type='post'
oov_tok = "<OOV>"

train_seq = tokenizer.texts_to_sequences(X_train)
train_pad_seq = pad_sequences(train_seq,maxlen=max_length,truncating=trunc_type, padding=pad_type)



valid_seq = tokenizer.texts_to_sequences(X_test)
valid_pad_seq = pad_sequences(valid_seq,maxlen=max_length)

training_labels_final = np.array(Y_train)
validation_labels_final = np.array(Y_test)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(vocab_size, embedding_dim, input_length=max_length),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(6, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 75, 32)            160000
#
#  flatten_1 (Flatten)         (None, 2400)              0
#
#  dense_3 (Dense)             (None, 6)                 14406
#
#  dense_4 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 174,413
# Trainable params: 174,413
# Non-trainable params: 0
# _________________________________________________________________

# %%
num_epochs = 10
history = model.fit(train_pad_seq, training_labels_final, epochs=num_epochs,
                    validation_data=(valid_pad_seq, validation_labels_final))
# Out:
# Epoch 1/10
# 1000/1000 [==============================] - 5s 4ms/step - loss: 0.6461 - accuracy: 0.6073 - val_loss: 0.6059 - val_accuracy: 0.6670
# Epoch 2/10
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.6013 - accuracy: 0.6682 - val_loss: 0.6101 - val_accuracy: 0.6601
# Epoch 3/10
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.5849 - accuracy: 0.6851 - val_loss: 0.6194 - val_accuracy: 0.6488
# Epoch 4/10
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.5681 - accuracy: 0.6998 - val_loss: 0.6293 - val_accuracy: 0.6450
# Epoch 5/10
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.5492 - accuracy: 0.7126 - val_loss: 0.6444 - val_accuracy: 0.6404
# Epoch 6/10
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.5311 - accuracy: 0.7272 - val_loss: 0.6576 - val_accuracy: 0.6342
# Epoch 7/10
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.5128 - accuracy: 0.7411 - val_loss: 0.6759 - val_accuracy: 0.6304
# Epoch 8/10
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.4952 - accuracy: 0.7537 - val_loss: 0.6884 - val_accuracy: 0.6277
# Epoch 9/10
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.4780 - accuracy: 0.7648 - val_loss: 0.7095 - val_accuracy: 0.6259
# Epoch 10/10
# 1000/1000 [==============================] - 3s 3ms/step - loss: 0.4608 - accuracy: 0.7742 - val_loss: 0.7376 - val_accuracy: 0.6230

# %% [markdown]
# **Predict a review**
#
# ---
#
# Now you can test this model. We need to tokenize the test data before pridicting. Try to change or add more review to test_reviews list here:

# %%
test_reviews = ["This movie is not good at all. I did not enjoyed much",
                "One of the best movie I have ever seen. Recommend everyone to watch this movie"]


# Create the sequences

test_sequences = tokenizer.texts_to_sequences(test_reviews)
test_padded = pad_sequences(test_sequences, padding=pad_type, maxlen=max_length)

classes = model.predict(test_padded)

# Closer to 1 means positive
for x in range(len(test_reviews)):
  print(test_reviews[x])
  print(classes[x])
  print('\n')
# Out:
# 1/1 [==============================] - 0s 18ms/step
# This movie is not good at all. I did not enjoyed much
# [0.4522577]
#
#
# One of the best movie I have ever seen. Recommend everyone to watch this movie
# [0.72242755]
